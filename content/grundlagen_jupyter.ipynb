# %% [markdown]
# # Jupyter Grundlagen
# Bei Jupyter-Notebooks kommt es auf die Reihenfolge an, in der Python-Felder ausgeführt werden.

# %% [markdown]
# <div style="padding: 5px; border: 5px solid #0076BD;">
#
# ## Aufgabe 1
# Ein Jupyter Notebook ist in sogenannte Zellen unterteilt. Dies sind Blöcke mit entweder Text oder Code, welche einzeln ausgeführt werden können.
# Die Textblöcke werden mit auch als Markdown bezeichnet, da mit speziellen Befehlen wie z.B. zwei Sternen ein Wort fett geschrieben werden kann. \*\*bold\*\* ergibt **bold**
# Füge nun zwei Zellen hinzu, indem du oben auf das Plus klickst.
#
# <img src="images/Jupyter_zelle.png" width="500">
#
# Du kannst dann im gleichen Menüband oben, die Art der Zelle auswählen.
#
# <img src="images/jupyter_dropdown.png" width="500">
#
# Wähle für eine Zelle die Art Markdown und für eine Zelle die Art Code.

# %% [markdown]
# <div style="padding: 5px; border: 5px solid #0076BD;">
#
# ## Aufgabe 2
# Füge nun in die eingefügte **Code** Zelle den folgenden Code ein:
# ```python
# print("Mein Name")
# ```
# Drücke danach wenn du in der Zelle bist enteder oben auf den Play-Button oder Drücke Ctrl+Enter um die Zelle auszuführen.
# Wo siehst du die Ausgabe des Codes?
#
# Füge nun in die **Markdown** Zelle, folgenden Text ein und drücke auch Ctrl+Enter oder den Play-Button.
#
# ```markdown
# **Dies** *ist* ein Text
# ### Titel 3
# ```

# %% [markdown]
# <div style="padding: 5px; border: 5px solid #0076BD;">
#
# ## Aufgabe 3
# Führe die folgenden Python-Eingabefelder in unterschiedlicher Reihenfolge aus. Verändere dabei zwischendurch auch immer wieder die Werte der Variablen a und b. Beobachte genau, was dabei passiert und halte deine Beobachtungen schriftlich fest.

# %%
print(a)

# %%
a = 23

# %%
b = 42

# %%
print (a)

# %%
print(b)

# %% [markdown]
# Beobachtungen bitte hierher

# %% [markdown]
# Dieses Notebook ist verändert nach https://inf-schule.de, CC BY-SA 4.0
